# %%
# !pip install langchain langchain_community duckduckgo-search google-serp-api wikipedia
# Out:
# Requirement already satisfied: langchain in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (0.3.7)
# Requirement already satisfied: langchain_community in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (0.3.5)
# Requirement already satisfied: duckduckgo-search in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (6.3.4)
# Requirement already satisfied: google-serp-api in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (1.0.5)
# Requirement already satisfied: wikipedia in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (1.4.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (0.1.139)
# Requirement already satisfied: numpy<2,>=1 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain_community) (2.6.1)
# Requirement already satisfied: click>=8.1.7 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from duckduckgo-search) (8.1.7)
# Requirement already satisfied: primp>=0.6.5 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from duckduckgo-search) (0.7.0)
# Requirement already satisfied: beautifulsoup4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from beautifulsoup4->wikipedia) (2.6)
# Requirement already satisfied: anyio in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)

# %%
# !pip install --upgrade langchain
# Out:
# ^C
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/bin/pip", line 7, in <module>
#     from pip._internal.cli.main import main
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load
# KeyboardInterrupt

# %%
# !pip install -U langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (0.2.6)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-openai) (0.3.15)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-openai) (1.54.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (0.1.139)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.7.0)
# Requirement already satisfied: sniffio in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.66.6)
# Requirement already satisfied: regex>=2022.1.18 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-openai) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (1.26.20)

# %%
import pandas as pd
import os
import openai
from langchain_openai import ChatOpenAI
from langchain.tools import DuckDuckGoSearchRun
from langchain.agents import initialize_agent, Tool
import logging
from multiprocessing import Pool, Manager, Lock
from functools import partial
import time
from tqdm import tqdm
import csv

# %%
def setup_agent(openai_api_key):
    """Initialize and return a LangChain agent with DuckDuckGo search capabilities."""
    llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0, openai_api_key=openai_api_key)
    duckduckgo_search = DuckDuckGoSearchRun()
    
    tools = [
        Tool(
            name="DuckDuckGo Search",
            func=duckduckgo_search.run,
            description="Useful for retrieving detailed information based on a given topic."
        )
    ]
    
    return initialize_agent(
        tools=tools,
        llm=llm,
        agent="zero-shot-react-description",
        verbose=True,
        handle_parsing_errors=True
    )

# %%
def search_and_summarize(agent, topic):
    """Perform detailed search and generate summary."""
    try:
        prompt = (
            f"Search for detailed and technical information on the topic: '{topic}' "
            "from a medical standpoint. Provide a comprehensive, detailed summary in paragraph form. "
            "Avoid using bullet points or lists. The summary should focus on technical and medical aspects "
            "with a high level of detail, suitable for a medical professional audience."
        )
        summary = agent.run(prompt)
        return summary
    except Exception as e:
        logging.error(f"Error summarizing topic '{topic}': {e}")
        return None

# %%
def generate_claim_triplet(agent, summary):
    """Generate claim triplets from a summary."""
    try:
        prompt = (
            f"Using the following detailed summary, generate three types of claims:\n\n"
            f"Summary:\n{summary}\n\n"
            "1) A supporting claim that paraphrases a key assertion.\n"
            "2) A contradictory claim that directly contradicts a key evidence provided in the summary.\n"
            "3) An ambiguous claim that either partially supports or contradicts, or presents elements that are neither clearly supported nor contradicted.\n\n"
            "Each claim should be one or two sentences long. Ideally, the claims should be generated from different key assertions or sections of the summary."
        )
        response = agent.run(prompt)

        supports = response.split("1) Supporting Claim:")[1].split("2) Contradictory Claim:")[0].strip() if "1) Supporting Claim:" in response else "N/A"
        contradicts = response.split("2) Contradictory Claim:")[1].split("3) Ambiguous Claim:")[0].strip() if "2) Contradictory Claim:" in response else "N/A"
        ambiguous = response.split("3) Ambiguous Claim:")[1].strip() if "3) Ambiguous Claim:" in response else "N/A"

        return supports, contradicts, ambiguous
    except Exception as e:
        logging.error(f"Error generating claims for summary: {e}")
        return "N/A", "N/A", "N/A"

# %%
def write_row(file_path, row_dict, file_lock):
    """Write a single row to the CSV file in a thread-safe manner."""
    with file_lock:
        file_exists = os.path.exists(file_path)
        mode = 'a' if file_exists else 'w'
        
        with open(file_path, mode, newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=list(row_dict.keys()))
            if not file_exists:
                writer.writeheader()
            writer.writerow(row_dict)

# %%
def process_topic(args):
    """Process a single topic and write results immediately."""
    topic, openai_api_key, processed_topics, file_lock, output_file, log_file = args
    
    if topic in processed_topics:
        return None
    
    try:
        agent = setup_agent(openai_api_key)
        summary = search_and_summarize(agent, topic)
        
        if summary:
            supports, contradicts, ambiguous = generate_claim_triplet(agent, summary)
            
            # Prepare result row
            result = {
                'Topic': topic,
                'Evidence': summary,
                'Supports': supports,
                'Contradicts': contradicts,
                'Ambiguous': ambiguous
            }
            
            # Write to output file immediately
            write_row(output_file, result, file_lock)
            
            # Write to log file
            write_row(log_file, {'Processed_Topic': topic}, file_lock)
            
            return result
            
    except Exception as e:
        logging.error(f"Error processing topic '{topic}': {e}")
    
    return None

# %%
def init_files(output_file, log_file):
    """Initialize output and log files with headers if they don't exist."""
    if not os.path.exists(output_file):
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['Topic', 'Evidence', 'Supports', 'Contradicts', 'Ambiguous'])
            writer.writeheader()
    
    if not os.path.exists(log_file):
        with open(log_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['Processed_Topic'])
            writer.writeheader()

# %%
# File paths
log_file = './process_log.csv'
output_file = './generated_claim_triplets_with_topics.csv'
input_file = "./categorized_content_links_unique.csv"

# OpenAI API key
# openai_api_key = "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"
openai_api_key = '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'

# Initialize logging
logging.basicConfig(level=logging.INFO)

# Initialize files
init_files(output_file, log_file)

# Load data
df = pd.read_csv(input_file)
topics = df.iloc[:, 1].astype(str) + " " + df.iloc[:, 2].astype(str)[:5]
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[29], line 17
#      14 init_files(output_file, log_file)
#      16 # Load data
# ---> 17 df = pd.read_csv(input_file)
#      18 topics = df.iloc[:, 1].astype(str) + " " + df.iloc[:, 2].astype(str)[:5]
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
topics
# Out:
# 0         Anaphylaxis Allergic reactions to seminal plasma
# 1                       Anaphylaxis Anaphylaxis in infants
# 2        Anaphylaxis Anaphylaxis in pregnant and breast...
# 3        Anaphylaxis Anaphylaxis induced by subcutaneou...
# 4                 Anaphylaxis Anaphylaxis: Acute diagnosis
#                                ...
# 31858                                                  NaN
# 31859                                                  NaN
# 31860                                                  NaN
# 31861                                                  NaN
# 31862                                                  NaN
# Length: 31863, dtype: object

# %%
def go_for_it():
    # Load processed topics
    processed_topics = set()
    if os.path.exists(log_file):
        log_df = pd.read_csv(log_file)
        processed_topics = set(log_df["Processed_Topic"])
    
    # Initialize multiprocessing resources
    manager = Manager()
    file_lock = manager.Lock()
    num_processes = min(os.cpu_count() - 1, 4)  # Use up to 4 processes or CPU count - 1
    
    # Prepare arguments for each topic
    process_args = [
        (topic, openai_api_key, processed_topics, file_lock, output_file, log_file)
        for topic in topics
    ]
    
    # Process topics in parallel with immediate output
    with Pool(num_processes) as pool:
        for _ in tqdm(pool.imap_unordered(process_topic, process_args), total=len(topics)):
            pass

# %%
go_for_it()
# Out:
#   0%|          | 0/31863 [00:00<?, ?it/s]Process SpawnPoolWorker-2:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-3:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-6:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-7:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-8:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-9:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-10:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-11:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-12:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-13:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-15:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-16:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-17:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-19:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-22:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-24:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-25:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-26:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-27:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-28:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-29:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-30:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-31:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-32:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-33:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-34:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-35:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-36:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-37:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-38:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-39:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-40:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-41:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-42:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-43:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-44:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-45:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-46:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-47:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-48:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-49:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-50:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-51:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-52:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-53:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-54:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-55:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-56:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-57:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-58:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-59:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-60:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-61:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-62:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-63:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-64:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-65:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-66:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# ...
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-91:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-92:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-93:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-94:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-95:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-96:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-97:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-98:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-99:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-100:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-101:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-102:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-103:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-104:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-105:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-106:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-107:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-108:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-109:
# Traceback (most recent call last):
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/rateria/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_topic' on <module '__main__' (built-in)>
#   0%|          | 0/31863 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py:853, in IMapIterator.next(self, timeout)
#     852 try:
# --> 853     item = self._items.popleft()
#     854 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 go_for_it()
#
# Cell In[17], line 21, in go_for_it()
#      19 # Process topics in parallel with immediate output
#      20 with Pool(num_processes) as pool:
# ---> 21     for _ in tqdm(pool.imap_unordered(process_topic, process_args), total=len(topics)):
#      22         pass
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/multiprocessing/pool.py:858, in IMapIterator.next(self, timeout)
#     856     self._pool = None
#     857     raise StopIteration from None
# --> 858 self._cond.wait(timeout)
#     859 try:
#     860     item = self._items.popleft()
#
# File ~/Code/cs-5787-final-project/.conda/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
